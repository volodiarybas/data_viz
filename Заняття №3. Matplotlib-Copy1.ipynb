# %%
import matplotlib.pyplot as plt

# %%
# Line

# %%
plt.plot([1,5,2,7,4,4])

# %%
x=[1,2,3,5,7]

# %%
y=[2,4,6,10,14]

# %%
plt.plot(x,y)

# %%
import numpy as np
numbers = np.arange(5)
numbers
# Out:
# array([0, 1, 2, 3, 4])

# %%
# https://matplotlib.org/2.1.2/api/_as_gen/matplotlib.pyplot.plot.html стилі ліній і маркерів

# %%
plt.plot(numbers)
plt.plot(numbers,2*numbers,'--r',alpha=1)
plt.plot(numbers**2)

# %%
plt.plot(numbers, color='#4BC565',linewidth=3,label='line')
plt.plot(numbers,2*numbers,linestyle="--",c='#425C48',alpha=0.5,label='another_line')
plt.plot(numbers**2,'x',markerfacecolor='blue',markersize=10,linewidth=3,label='dots')
plt.legend()

# %%
plt.plot(numbers, color='#4BC565',linewidth=3)
plt.plot(numbers,2*numbers,linestyle="--",c='#425C48',alpha=1)
plt.plot(numbers**2,'x',markerfacecolor='blue',markersize=10,linewidth=3)
plt.legend(['line','another_line','dots'])

# %%
plt.figure(figsize=(10,8))
plt.plot(numbers)
plt.figure()
plt.plot(2*numbers,color='red')

# %%
import pandas as pd
test=pd.read_csv('data/test.csv')
test
# Out:
#       age     sex      height     weight product   amount       date  \
# 0      49    Male  187.431987  81.008363      A2  1000000  2016/12/6
# 1      79    Male  171.632630  71.067812      C1     2000   2016/9/3
# 2      78  Female  163.543983  64.032098      A1  4000000  2015/4/10
# 3      26    Male  150.391858  52.322910      A3  1000000  2016/4/17
# 4      14    Male  165.835167  67.008154      A3  4000000  2015/1/26
# ...   ...     ...         ...        ...     ...      ...        ...
# 9995   21    Male  185.174944  62.893499      C3     3000  2015/3/11
# 9996   34    Male  157.581442  58.889901      C3     2000  2016/3/27
# 9997   36    Male  177.676066  85.277018      A3  6000000  2016/3/16
# 9998   18    Male  166.757782  64.254215      B1  6000000  2015/6/17
# 9999   42  Female  158.656634  53.299956      A2  3000000  2016/8/15
#
#       medical_info_a1  medical_info_a2  medical_info_a3  ...  \
# 0                 302              212                1  ...
# ...

# %%
#Bars

# %%
test['sex'].value_counts().plot(kind='bar',xlabel = 'sex',ylabel='count')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
test['product'].value_counts()
# Out:
# A3    1986
# A1    1913
# A2    1066
# C1    1043
# C3    1035
# D1    1006
# C2     506
# E1     488
# B1     407
# B3     368
# B2     182
# Name: product, dtype: int64

# %%
plt.figure(figsize=(6,6))
data = test['product'].value_counts()
x=data.index.values
y=data.values
plt.bar(x,y,color=['r','b'])
plt.ylabel("count")
plt.legend(['smth'])

# %%
pl=pd.read_csv('data/PL_stats.csv', index_col=0)
pl
# Out:
#                       wins  losses  goals  total_yel_card  total_red_card  \
# team
# Manchester United     28.0     5.0   83.0            60.0             1.0
# Chelsea               24.0     3.0   64.0            62.0             4.0
# Liverpool             20.0    10.0   57.0            44.0             0.0
# Arsenal               19.0     8.0   63.0            59.0             3.0
# Tottenham Hotspur     17.0    12.0   57.0            48.0             3.0
# ...                    ...     ...    ...             ...             ...
# Huddersfield Town      9.0    19.0   28.0            62.0             3.0
# Swansea City           8.0    21.0   28.0            51.0             1.0
# Southampton            7.0    16.0   37.0            63.0             2.0
# Stoke City             7.0    19.0   35.0            62.0             1.0
# West Bromwich Albion   6.0    19.0   31.0            73.0             1.0
#
# ...

# %%
y=[]
y.extend(pl.loc['Manchester City',['total_yel_card']].sum().values)
y
# Out:
# [731.0]

# %%
x = ['Manchester United', 'Manchester City', 'Chelsea', 'Liverpool', 'Arsenal']
y1 = []
for i in x:
    y1.extend(pl.loc[i,['total_yel_card']].sum().values)
y2 = []
for i in x:
    y2.extend(pl.loc[i,['total_red_card']].sum().values)
y1
# Out:
# [722.0, 731.0, 715.0, 643.0, 685.0]

# %%
plt.figure(figsize=(10,6))
plt.bar(x,y1,width=0.4)
plt.bar(x,y2,width=0.4, align='center')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,6))
plt.bar(x,y1,width=0.4)
plt.bar(x,y2,width=0.4, align='edge')
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np



width = 0.4
x_pos = np.arange(len(x))  # Generate an array of x-axis positions for the ticks

plt.figure(figsize=(10, 6))
plt.bar(x_pos, y1, width=width, align='edge', label='Y1')
plt.bar(x_pos + width, y2, width=width, align='edge', label='Y2')
plt.xlabel('Teams')
plt.ylabel('Values')
plt.title('Comparison of Y1 and Y2 for different teams')
plt.xticks(x_pos + width / 2, x)  # Set the x-axis tick positions and labels
plt.legend()

# %%
plt.figure(figsize=(10,6))
plt.bar(x,y1,width=0.4, bottom=y2)
plt.bar(x,y2,width=0.4)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,6))
plt.barh(x,y1,height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
# Гістограми

# %%
nums = 10*np.random.rand(25)
nums
plt.hist(nums,bins=5,edgecolor='black')
# Out:
# (array([6., 6., 3., 4., 6.]),
#  array([0.08569904, 2.02796983, 3.97024061, 5.9125114 , 7.85478218,
#         9.79705296]),
#  <BarContainer object of 5 artists>)

# %%
nums
# Out:
# array([0.08569904, 9.04702976, 7.8764587 , 6.62457207, 3.06312052,
#        5.43763819, 1.76305449, 0.41213088, 5.6320859 , 3.48248498,
#        2.25406227, 3.00154933, 6.44248665, 8.62720578, 3.71838472,
#        9.52572418, 2.19721061, 1.87995212, 6.84597797, 6.68236685,
#        4.66641423, 9.79705296, 1.74070212, 8.02555174, 1.13987018])

# %%
hist, bins = np.histogram(nums, bins=5, range=(nums.min(), nums.max()))
hist
bins
# Out:
# array([0.08569904, 2.02796983, 3.97024061, 5.9125114 , 7.85478218,
#        9.79705296])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = [10, 15, 8, 12, 7]

# Create the histogram
hist, bins, _ = plt.hist(data, bins=5, edgecolor='black', alpha=0.7)

# Add value labels on top of each bar
for i, value in enumerate(hist):
    plt.text(bins[i] + (bins[i + 1] - bins[i]) / 2, value, str(int(value)), ha='center', va='bottom')

plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Histogram with Value Labels')
plt.grid(True)
plt.show()

# %%
titanic=pd.read_csv('data/titanic.csv')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
plt.figure(figsize=(12,7))
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]
plt.hist(first_class, label="1st Class", alpha=0.8, color="#f1c40f", bins=20)
plt.hist(second_class, label="2nd Class", alpha=0.6, color="#3498db", bins=20)
plt.hist(third_class, label="3rd Class", alpha=0.4, color="#e74c3c", bins=20)
plt.xticks([10*i for i in range(9)])
plt.legend()
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
# Pie Chart

# %%
classes = titanic['pclass'].value_counts()
x = classes.index.values
y = classes.values

# %%
plt.pie(y, labels=x, autopct="%1.1f%%", shadow=True, explode=(0,0.1,0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x1ed71f6c790>,
# ...
#  [Text(-0.1434698270862726, 1.0906036900340266, '3'),
#   Text(-0.6107751910007475, -1.0329344926267108, '1'),
#   Text(0.9444494511828991, -0.740280510455544, '2')],
#  [Text(-0.07825626931978504, 0.5948747400185599, '54.2%'),
#   Text(-0.35628552808376934, -0.6025451206989146, '24.7%'),
#   Text(0.5509288465233577, -0.431830297765734, '21.2%')])

# %%
plt.pie(y, labels=x, autopct="%1.1f%%", shadow=True, wedgeprops=dict(width=0.5), explode=(0,0,0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x1ed6f64ceb0>,
# ...
#  [Text(-0.1434698270862726, 1.0906036900340266, '3'),
#   Text(-0.5598772584173519, -0.9468566182411515, '1'),
#   Text(0.9444494511828991, -0.740280510455544, '2')],
#  [Text(-0.07825626931978504, 0.5948747400185599, '54.2%'),
#   Text(-0.3053875955003737, -0.5164672463133554, '24.7%'),
#   Text(0.5509288465233577, -0.431830297765734, '21.2%')])

# %%
# Scatter Plot

# %%
pl['points']=pl['wins']*3 + 38 - pl['wins'] - pl['losses']
x = pl[pl['season']=='2017-2018'].points
y1 =  pl[pl['season']=='2017-2018'].goals
y2 =  pl[pl['season']=='2017-2018'].total_yel_card

# %%
plt.scatter(x,y1, marker = '*', s=25, color = 'g')
plt.scatter(x,y2, marker = 'x', s=25, color = 'y')

# %%
# Кілька графіків на одному полотні

# %%
plt.figure(figsize=(10,10))
plt.subplots(2,2)
plt.suptitle("Multiple plots", fontsize=20)
plt.subplot(2,2,1)
plt.plot(numbers, color='#4BC565',linewidth=3,label='1')
plt.legend()
plt.title("1st")
plt.subplot(2,2,2)
plt.plot(numbers,2*numbers,linestyle="--",c='#425C48',alpha=1,label='1')
plt.title("2nd")
plt.subplot(2,2,3)
plt.plot(numbers**2,'x',markerfacecolor='blue',markersize=10,linewidth=3)
plt.title("3rd")
plt.subplot(2,2,4)
plt.plot(numbers**3,'.',markerfacecolor='blue',markersize=10,linewidth=3,label='4')
plt.title("4th");
plt.legend();
plt.tight_layout();
plt.show();

# %%
[].append(pl[pl['season']=='2017-2018'].loc['Arsenal','goals'])

# %%
x = ['Manchester United', 'Manchester City', 'Chelsea', 'Liverpool', 'Arsenal']
y1 = []
for i in x:
    y1.append(pl[pl['season']=='2017-2018'].loc[i,'goals'])
y2 = []
for i in x:
    y2.append(pl[pl['season']=='2017-2018'].loc[i,'wins'])

# %%
fig, axs = plt.subplots(1,2,figsize=(10,6))
axs[0].bar(x,y1,label='l1')
axs[0].set_xticks(x,['MU','MC','CHE','LIV','ARS'])
axs[1].bar(x,y2,color='green',label='l2')
axs[1].set_xticks(x,['MU','MC','CHE','LIV','ARS'])
fig.legend(facecolor = 'yellow', title= 'legend', fontsize=15, edgecolor = 'r')

# %%
fig, ax = plt.subplots()
ax.plot(y1)
ax.plot(y2)

# %%
plt.figure(figsize=(6,6))
plt.suptitle("Multiple plots", fontsize=20)
plt.subplot(2,2,1)
plt.plot(numbers, color='#4BC565',linewidth=3)
plt.title("1st")
plt.subplot(2,2,2)
plt.plot(numbers,2*numbers,linestyle="--",c='#425C48',alpha=1)
plt.title("2nd")
plt.subplot(2,2,3)
plt.plot(numbers**2,'x',markerfacecolor='blue',markersize=10,linewidth=3)
plt.title("3rd")
# Out:
# Text(0.5, 1.0, '3rd')

# %%
array = test['product'].value_counts().sort_index().index.values
array
# Out:
# array(['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3', 'D1', 'E1'],
#       dtype=object)

# %%
colors=['#C5B8D3','#959B68','#D6ABCC','#6C7CA4','#20392D','#F60750','#5BF8E2','#36F98A','#07FEDB','#F31C9B', '#6446FB']

array = test['product'].value_counts().sort_index().index.values
fig, ax = plt.subplots(3,4,figsize=(12,12))
arr2 = test.loc[test['product']==array[0],['age']].values
arr3 = [item for sublist in arr2 for item in sublist]
for i in range(3):
    for j in range(4):
        if 4*i+j<=10:
            arr2 = test.loc[test['product']==array[4*i+j],['age']].values
            arr3 = [item for sublist in arr2 for item in sublist]
        else: break
        ax[i][j].hist(arr3,bins=6, color=colors[4*i+j])
        ax[i][j].set_title(array[4*i+j])
        ax[i][j].set_xlim((-10,100))
plt.tight_layout()
fig.delaxes(ax[-1, -1])

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
plt.plot()
# Out:
# []

# %%
# Компонування графіків з gridspec

# %%
import matplotlib.gridspec as gridspec

# %%
x = [1, 2, 3, 4, 5]
y1 = [9, 4, 2, 4, 9]
y2 = [1, 7, 6, 3, 5]
fg = plt.figure(figsize=(7, 3), constrained_layout=True)
gs = gridspec.GridSpec(ncols=2, nrows=1, figure=fg)
fig_ax_1 = fg.add_subplot(gs[0, 0])
plt.plot(x, y1)
fig_ax_2 = fg.add_subplot(gs[0, 1])
plt.plot(x, y2)

# %%
x = [1, 2, 3, 4, 5]
y1 = [9, 4, 2, 4, 9]
y2 = [1, 7, 6, 3, 5]
y3 = [-7, -4, 2, -4, -7]

# %%
fg = plt.figure(figsize=(9, 4), constrained_layout=True)
gs = fg.add_gridspec(2, 2)
fig_ax_1 = fg.add_subplot(gs[0, :])
plt.plot(x, y2)
fig_ax_2 = fg.add_subplot(gs[1, 0])
plt.plot(x, y1)
fig_ax_3 = fg.add_subplot(gs[1, 1])
plt.plot(x, y3)

# %%
fg = plt.figure(figsize=(5, 5),constrained_layout=True)
widths = [1, 3]
heights = [2, 1]
gs = fg.add_gridspec(ncols=2, nrows=2, width_ratios=widths, 
height_ratios=heights)
fig_ax_1 = fg.add_subplot(gs[0, 0])
fig_ax_1.set_title('w:1, h:2')
fig_ax_2 = fg.add_subplot(gs[0, 1])
fig_ax_2.set_title('w:3, h:2')
fig_ax_3 = fg.add_subplot(gs[1, 0])
fig_ax_3.set_title('w:1, h:1')
fig_ax_4 = fg.add_subplot(gs[1, 1])
fig_ax_4.set_title('w:3, h:1')
plt.tight_layout()
# Out:
# C:\Users\taras\AppData\Local\Temp\ipykernel_2484\1593608030.py:14: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Завдання

# %% [markdown]
# ## 1. Відтворіть наступну діаграму розсіювання. Стиль, який використовується - 'seaborn-v0_8-white'.
#    <br> Дані: <br>
#    x = [ 0.76460811,  0.07399473, -0.58423189,  0.49622908, -1.66891526,
#         0.46635461,  1.54561547, -0.17172909, -0.8022902 ,  0.27431508,
#         0.81461323,  0.8406768 ,  0.40346947,  0.87522933, -0.13784721,
#         0.45933574, -1.46555781,  0.45870287,  0.07898396, -1.55417461,
#         0.54465767, -0.6721775 ,  0.9960084 , -0.48157428,  2.77558313]
#
# ![title](1.png)
#
#
#
#
# ## 2. Відтворіть наступну діаграму. Стиль, який використовується - 'seaborn-v0_8-white'. Колір - "#6d597a". Дані з файлу 'IMDB'.
#    <br> ![image-2.png](attachment:image-2.png)
# ## 3. Нехай маємо дані <br>
#    income = [ 40.85948226,  68.51222165,  59.92733209, 175.46693042,
#         40.08668635,  85.16169195, 336.86500136,  79.34817538,
#         63.35538498, 111.27951632, 193.02271981,  73.91525881,
#        363.0717243 , 191.66971963,  61.53727868,  31.74575135,
#         92.69143648, 122.29100703, 133.09564536, 157.50241746,
#        177.28637387, 106.6612455 , 602.2066291 ,  80.07407901,
#        425.45254649, 330.03614809,  15.70549866,  43.11125981,
#        169.94277748,  21.4645859 , 212.79269176,  49.49038401,
#         35.30461224,  17.52991241,  93.5374855 , 516.9842398 ,
#        219.44092865,  43.50219628, 116.36693656,  86.01745934,
#         65.55389447, 519.09250193, 173.90099585, 144.30296248,
#         86.05947869,  24.87822244,  49.79630006,  43.28753667,
#         24.26544694,  20.69351239] <br>
#     <br> spend = [40.55948226,
#  67.01222165,
#  57.92733209,
#  173.46693042,
#  39.786686350000004,
#  83.16169195,
#  336.16500136,
#  78.64817538,
#  62.655384979999994,
#  110.57951632,
#  192.72271981,
#  73.21525881,
#  361.0717243,
#  190.66971963,
#  60.53727868,
#  31.04575135,
#  90.69143648,
#  120.29100703,
#  132.39564536,
#  156.80241746000002,
#  175.78637387,
#  105.6612455,
#  600.2066291,
#  78.07407901,
#  423.95254649,
#  329.33614809,
#  15.40549866,
#  42.11125981,
#  167.94277748,
#  19.9645859,
#  212.09269176,
#  47.99038401,
#  33.30461224,
#  16.52991241,
#  92.8374855,
#  516.2842397999999,
#  217.94092865,
#  42.00219628,
#  116.06693656,
#  85.01745934,
#  64.85389447,
#  518.39250193,
#  173.20099585,
#  143.60296248,
#  85.35947869,
#  24.578222439999998,
#  49.49630006,
#  42.987536670000004,
#  23.26544694,
#  18.69351239]
#   <br>
#    Побудуйте гістограму для spend (bins = 8).
#    <br> Створіть окремо лінійний графік з показником 'roi' (roi - Return on Investment), який рахується як відношення income до spend. За x взяти цілі числа від 0 до 50.
#    <br> ![image-3.png](attachment:image-3.png)
#   <br>
#   ## 4. На одній 'осі' побудувати діаграму для голів за сезон команди 'Manchester City' та лінійний графік з перемогами за сезон. Щоб вмістити усі дати використовуй plt.xticks(rotation=45), де 45 це кут повороту.<br>

# %%
x = [ 0.76460811,  0.07399473, -0.58423189,  0.49622908, -1.66891526,
        0.46635461,  1.54561547, -0.17172909, -0.8022902 ,  0.27431508,
        0.81461323,  0.8406768 ,  0.40346947,  0.87522933, -0.13784721,
        0.45933574, -1.46555781,  0.45870287,  0.07898396, -1.55417461,
        0.54465767, -0.6721775 ,  0.9960084 , -0.48157428,  2.77558313]

# %%
y = [  6.83988891,  11.44579069,  12.3393238 ,  11.23232984,
       -23.74645497, -19.76695688,  -0.4507766 ,  17.82520272,
         9.11691314,  -9.50473107,  -3.37679637,  -4.72001142,
         8.72540995,  -3.42640783,   0.302766  ,   1.29422886,
       -11.74897084,  -0.07188628,  -1.53206832,   1.9873889 ,
         2.63039182, -12.75898802,  -2.06608041,  -3.57347718,
         2.71255687]

# %%
plt.style.use('seaborn-v0_8-white')
plt.scatter(x,y,label = 'random', marker = 'x', c = 'y')
plt.legend()

# %%
plt.style.use('seaborn-v0_8-white')
plt.scatter(x,y,label = 'random', marker = 'x', c = y, cmap = 'Blues')
plt.colorbar()
plt.legend()

# %%
plt.style.use('seaborn-v0_8-white')
plt.scatter(x,y,label = 'random', marker = 'x', c = 'y', cmap = 'Blues')
plt.colorbar()
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.style.use('seaborn-v0_8-white')
#       2 plt.scatter(x,y,label = 'random', marker = 'x', c = 'y', cmap = 'Blues')
#       3 plt.colorbar()
#
# NameError: name 'plt' is not defined

# %%
imdb = pd.read_csv('data\IMDB.csv')
imdb['Type'].value_counts()
imdb.loc[imdb['Type'] == 'Not Rated',['Type']] = 'NR'
imdb
# Out:
#                         Name       Year Episodes   Type  Rating  \
# 0            1. Breaking Bad  2008–2013   62 eps  TV-MA     9.5
# 1         2. Planet Earth II       2016    6 eps   TV-G     9.5
# 2            3. Planet Earth       2006   11 eps  TV-PG     9.4
# 3        4. Band of Brothers       2001   10 eps  TV-MA     9.4
# 4               5. Chernobyl       2019    5 eps  TV-MA     9.4
# ..                       ...        ...      ...    ...     ...
# 245  246. RuPaul's Drag Race      2009–  212 eps    NaN     8.5
# 246         247. Foyle's War  2002–2015   28 eps    NaN     8.6
# 247           248. Southland  2009–2013   43 eps    NaN     8.5
# 248         249. Kardes Payi  2014–2015   35 eps    NaN     8.6
# 249     250. Big Little Lies  2017–2019   14 eps    NaN     8.5
#
#                                              Image-src  \
# 0    https://m.media-amazon.com/images/M/MV5BYmQ4YW...
# 1    https://m.media-amazon.com/images/M/MV5BMGZmYm...
# ...

# %%
plt.bar(imdb['Type'].value_counts().index.values, imdb['Type'].value_counts().values, color="#6d597a")
plt.title('Best TV shows on IMDB by type')
# Out:
# Text(0.5, 1.0, 'Best TV shows on IMDB by type')

# %%
new_list = 100*np.random.lognormal(0, 1, 50)
new_list
y = new_list = 10*np.random.lognormal(0, 1, 50)
y
# Out:
# array([ 28.42220157,   7.33023638,   6.57463674,  10.69672539,
#        127.47405221,   2.79932599,  11.42690469,  36.67241663,
#          5.70711825,   5.92813393,   2.80377991,   5.8086219 ,
#          2.43436598,   8.13471222,  13.56107732,   9.82958442,
#         26.19935511,   7.86575095,   8.15823099,  16.42397738,
#          1.43421917,   1.61654963,   9.41652942,  33.39361697,
#          7.5039593 ,  13.90562798,   6.82657886,   5.54805614,
#          2.72933575,  14.62713205,  12.41745973,  65.97027337,
#          7.45254673,  38.57884373,   7.78446521,  25.41921051,
#         22.87789821,  15.78888354,   2.73527499,  21.18362512,
#          6.35075127,   4.90382366,  24.30179295,  14.26883516,
#         17.67347722,   5.90122266,  22.1428277 ,  41.01673645,
#         52.15377094,  20.96992288])

# %%
x = [ 40.85948226,  68.51222165,  59.92733209, 175.46693042,
        40.08668635,  85.16169195, 336.86500136,  79.34817538,
        63.35538498, 111.27951632, 193.02271981,  73.91525881,
       363.0717243 , 191.66971963,  61.53727868,  31.74575135,
        92.69143648, 122.29100703, 133.09564536, 157.50241746,
       177.28637387, 106.6612455 , 602.2066291 ,  80.07407901,
       425.45254649, 330.03614809,  15.70549866,  43.11125981,
       169.94277748,  21.4645859 , 212.79269176,  49.49038401,
        35.30461224,  17.52991241,  93.5374855 , 516.9842398 ,
       219.44092865,  43.50219628, 116.36693656,  86.01745934,
        65.55389447, 519.09250193, 173.90099585, 144.30296248,
        86.05947869,  24.87822244,  49.79630006,  43.28753667,
        24.26544694,  20.69351239]
y = [ i - np.random.choice([1,1.5,2,0.3,0.7]) for i in x]
y = [40.55948226,67.01222165,57.92733209,173.46693042,39.786686350000004,83.16169195,336.16500136,78.64817538,
 62.655384979999994,110.57951632,192.72271981,73.21525881,361.0717243,190.66971963,60.53727868,31.04575135,90.69143648,120.29100703,132.39564536,156.80241746000002,175.78637387,105.6612455,600.2066291,78.07407901,423.95254649,329.33614809,15.40549866,42.11125981,167.94277748,19.9645859,212.09269176,47.99038401,33.30461224,16.52991241,92.8374855,516.2842397999999,217.94092865,42.00219628,116.06693656,85.01745934,64.85389447,518.39250193,173.20099585,143.60296248,85.35947869,24.578222439999998,49.49630006,42.987536670000004,23.26544694,18.69351239]
z = [i[0]/i[1] for i in zip(x,y)]
z
# Out:
# [1.0073965441194959,
#  1.0223839765801885,
#  1.0345260160936234,
#  1.0115295750905235,
#  1.0075402107469047,
#  1.0240495347449456,
#  1.0020823107615844,
#  1.0089003972007977,
#  1.0111722240669887,
#  1.0063302863251302,
#  1.0015566405470813,
#  1.009560848535912,
#  1.005539065690833,
#  1.0052446712668406,
#  1.0165187471555501,
#  1.0225473686273017,
#  1.0220527987826178,
#  1.0166263468016459,
#  1.0052871829590513,
#  1.0044642168873357,
#  1.0085330846013656,
#  1.0094642079531422,
#  1.0033321857890822,
#  1.0256166966727054,
#  1.003538131832015,
#  1.0021254879066865,
#  1.0194735663298549,
#  1.0237466179950887,
#  1.0119088181701543,
#  1.075133038446843,
#  1.003300443754998,
#  1.031256261664575,
#  1.0600517425510791,
#  1.0604963883169178,
#  1.0075400577280822,
#  1.0013558422784148,
#  1.0068825989193104,
#  1.035712418226907,
#  1.0025847154141516,
#  1.0117622898609664,
#  1.0107934921367567,
#  1.0013503281729461,
#  1.0040415472010693,
# ...

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))
ax[0].hist(x,label='spend',bins = 8) 
ax[0].legend()
ax[1].plot(z,label='roi', c='y')
ax[1].legend()

# %%
x = [item for sublist in pl.loc['Manchester City',['season']].values for item in sublist]
y1 = [item for sublist in pl.loc['Manchester City',['goals']].values for item in sublist]
y2 = [item for sublist in pl.loc['Manchester City',['wins']].values for item in sublist]

# %%
plt.figure(figsize=(10,6))
plt.plot(x,y2,label='wins')
plt.bar(x,y1,label='goals',color='y')
plt.xlabel('season')
plt.xticks(rotation=45)
plt.legend()
